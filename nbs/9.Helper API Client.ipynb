# %%
import setup
setup.init_django()

# %%
import helpers.client as helper_clients

# %%
a_dataset=helper_clients.AlphaVantageAPIClient().get_stock_data()

# %% [markdown]
# b_dataset=helper_clients.PolygonAPIClient().get_stock_data()

# %%
a_dataset
# Out:
# [{'open_price': Decimal('184.6621'),
#   'close_price': Decimal('184.5726'),
#   'high_price': Decimal('184.6621'),
#   'low_price': Decimal('184.5428'),
#   'number_of_trades': None,
#   'volume': 2358,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 59, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.4931'),
#   'close_price': Decimal('184.5229'),
#   'high_price': Decimal('184.6422'),
#   'low_price': Decimal('184.4931'),
#   'number_of_trades': None,
#   'volume': 200,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 58, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.4135'),
#   'close_price': Decimal('184.4533'),
#   'high_price': Decimal('184.6422'),
#   'low_price': Decimal('184.4135'),
#   'number_of_trades': None,
#   'volume': 4017,
#   'volume_weighted_average': None,
#   'time': datetime.datetime(2024, 2, 1, 0, 57, tzinfo=<UTC>)},
#  {'open_price': Decimal('184.4036'),
# ...
